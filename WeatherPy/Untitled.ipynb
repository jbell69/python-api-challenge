# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# %%
weather_response = requests.get('https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/CMEAnalysis?startDate=2016-01-01&endDate=2019-09-30&mostAccurateOnly=true&speed=500&halfAngle=30&catalog=ALL')

weather_json = weather_response.json()
weather_json
# Out:
# [{'time21_5': '2016-01-01T23:12Z',
#   'latitude': -34.0,
#   'longitude': 73.0,
#   'halfAngle': 37.0,
#   'speed': 1588.0,
#   'type': 'O',
#   'isMostAccurate': True,
#   'associatedCMEID': '2016-01-01T23:12:00-CME-001',
#   'note': '',
#   'catalog': 'SWRC_CATALOG'},
#  {'time21_5': '2016-01-06T17:59Z',
#   'latitude': -7.0,
#   'longitude': 138.0,
#   'halfAngle': 45.0,
#   'speed': 940.0,
#   'type': 'C',
#   'isMostAccurate': True,
#   'associatedCMEID': '2016-01-06T14:24:00-CME-001',
#   'note': '',
#   'catalog': 'SWRC_CATALOG'},
#  {'time21_5': '2016-01-26T23:20Z',
#   'latitude': -30.0,
#   'longitude': 55.0,
#   'halfAngle': 35.0,
#   'speed': 820.0,
#   'type': 'C',
#   'isMostAccurate': True,
#   'associatedCMEID': '2016-01-26T18:12:00-CME-001',
#   'note': '',
#   'catalog': 'SWRC_CATALOG'},
#  {'time21_5': '2016-01-30T01:42Z',
#   'latitude': -24.0,
#   'longitude': 85.0,
#   'halfAngle': 35.0,
#   'speed': 856.0,
#   'type': 'C',
#   'isMostAccurate': True,
# ...

# %%
weather_response = requests.get('https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/GST?startDate=2016-01-01&endDate=2019-01-30')
weather_json = weather_response.json()
weather_json
# Out:
# [{'gstID': '2016-01-21T03:00:00-GST-001',
#   'startTime': '2016-01-21T03:00Z',
#   'allKpIndex': [{'observedTime': '2016-01-21T06:00Z',
#     'kpIndex': 6,
#     'source': 'NOAA'}],
#   'linkedEvents': [{'activityID': '2016-01-15T00:00:00-CME-001'},
#    {'activityID': '2016-01-21T10:00:00-HSS-001'}]},
#  {'gstID': '2016-02-16T18:00:00-GST-001',
#   'startTime': '2016-02-16T18:00Z',
#   'allKpIndex': [{'observedTime': '2016-02-16T21:00Z',
#     'kpIndex': 6,
#     'source': 'NOAA'},
#    {'observedTime': '2016-02-16T21:00Z', 'kpIndex': 6, 'source': 'NOAA'}],
#   'linkedEvents': [{'activityID': '2016-02-16T01:55:00-HSS-001'}]},
#  {'gstID': '2016-02-17T21:00:00-GST-001',
#   'startTime': '2016-02-17T21:00Z',
#   'allKpIndex': [{'observedTime': '2016-02-18T00:00Z',
#     'kpIndex': 6,
#     'source': 'NOAA'}],
#   'linkedEvents': [{'activityID': '2016-02-16T01:55:00-HSS-001'}]},
#  {'gstID': 'none',
#   'startTime': '2016-02-17T21:00Z',
# ...

# %%
weather_response = requests.get('https://kauai.ccmc.gsfc.nasa.gov/DONKI/WS/get/FLR?startDate=2016-01-01&endDate=2019-01-30')
weather_json = weather_response.json()
weather_json

# Transform json input to python objects
input_list = weather_json
# Filter python objects with list comprehensions
output_list = [x for x in input_list if x['classType'][0] == 'M' or x['classType'][0] == 'X']

# Transform python object back into json
#output_json = json.dumps(output_dict)

# Show json
print(json.dumps(output_list, indent = 2))
# Out:
# [
#   {
#     "flrID": "2016-01-01T23:00:00-FLR-001",
#     "instruments": [
#       {
#         "id": 11,
#         "displayName": "GOES15: SEM/XRS 1.0-8.0"
#       }
#     ],
#     "beginTime": "2016-01-01T23:00Z",
#     "peakTime": "2015-01-02T00:10Z",
#     "endTime": null,
#     "classType": "M2.3",
#     "sourceLocation": "S21W73",
#     "activeRegionNum": 12473,
#     "linkedEvents": [
#       {
#         "activityID": "2016-01-01T23:12:00-CME-001"
#       },
#       {
#         "activityID": "2016-01-02T02:48:00-SEP-001"
#       },
#       {
#         "activityID": "2016-01-02T04:30:00-SEP-001"
#       }
#     ]
#   },
#   {
#     "flrID": "2016-02-12T10:37:00-FLR-001",
#     "instruments": [
#       {
#         "id": 11,
#         "displayName": "GOES15: SEM/XRS 1.0-8.0"
#       }
#     ],
#     "beginTime": "2016-02-12T10:37Z",
#     "peakTime": "2016-02-12T10:47Z",
#     "endTime": "2016-02-12T10:53Z",
#     "classType": "M1.0",
#     "sourceLocation": "N11W14",
# ...
